# %% [markdown]
# # Setup

# %%
import os
os.environ["XLA_FLAGS"] = "--xla_force_host_platform_device_count=8"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_auc_score
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import FunctionTransformer, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %% [markdown]
# # Dataset

# %%
import pandas as pd
cols = ['preprocess', 'label',
        'NEG', 'POS', 'NEU',
        'num_word', 'num_char', 'num_hashtag', 'num_url',
        'num_like_post', 'num_comment_post', 'num_share_post',
        'hour', 'weekday', 'day', 'month', 'year']
df = pd.read_csv('Data/data_after_preprocessing_text_sa_timestamp.csv')

# %%
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4106 entries, 0 to 4105
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   preprocess        4106 non-null   object
#  1   label             4106 non-null   int64
#  2   NEG               4106 non-null   float64
#  3   POS               4106 non-null   float64
#  4   NEU               4106 non-null   float64
#  5   num_word          4106 non-null   int64
#  6   num_char          4106 non-null   int64
#  7   num_hashtag       4106 non-null   int64
#  8   num_url           4106 non-null   int64
#  9   num_like_post     3998 non-null   object
#  10  num_comment_post  4094 non-null   object
#  11  num_share_post    3339 non-null   object
#  12  hour              4106 non-null   int64
#  13  weekday           4106 non-null   int64
#  14  day               4106 non-null   int64
#  15  month             4106 non-null   int64
#  16  year              4106 non-null   int64
# dtypes: float64(3), int64(10), object(4)
# memory usage: 545.5+ KB
# None
#                                           preprocess  label       NEG  \
# 0  cần các bậc phụ_huynh xã ngũ thái lên_tiếng kh...      1  0.985327
# 1  kêu_gọi ăn_chay cầu_nguyện xin chúa cứu khỏi d...      1  0.659123
# 2  giàn khoan dầu_khí gặp sự_cố chết người giàn k...      1  0.929886
# 3  thuận_lợi có ca dương_tính cv19 rồi đó mọi ngư...      1  0.004563
# 4  sa_pa cho 9 người khách nước_ngoài đi cùng chu...      1  0.038136
#
#         POS       NEU  num_word  num_char  num_hashtag  num_url num_like_post  \
# 0  0.004864  0.009808        34       182            0        0            45
# 1  0.213645  0.127232        10        62            0        0           979
# 2  0.016793  0.053320        41       212            0        0            85
# 3  0.982044  0.013393        28       151            0        0           114
# 4  0.090191  0.871673        13        65            0        0           166
#
#   num_comment_post num_share_post  hour  weekday  day  month  year
# 0               15              8     6        1   17      3  2020
# 1               39            138    19        0   10      2  2020
# 2               13             61    12        3   16      4  2020
# 3               12              5    10        0    3      8  2020
# 4                4             21     2        5    7      3  2020

# %%
df[df['num_share_post'] == 'unknown']
# Out:
#                                              preprocess  label       NEG  \
# 5     mọi người ra đường nhớ đeo khẩu_trang nhã đã c...      1  0.005398
# 11    danh_hài thuý nga qua_đời để lại gia_tài triệu...      1  0.007171
# 12    quanh khu_vực xuân mai mọi người cẩn_trọng chú...      1  0.965107
# 14    ban muốn mình là người sống_sót trống con_số 9...      1  0.066749
# 18    vụ bắt_cóc con_nít thôn 5 nông sơn sao không t...      1  0.202187
# ...                                                 ...    ...       ...
# 3978  mọi người ơi hạn_chế za đường nhé vì 3nguoi nh...      1  0.970915
# 4003  thông_báo bệnh_viện thái_hoà hồng_ngự mới tiếp...      1  0.179704
# 4066  tin nóng đã tìm ra nguyên nhiên gây tử_vong ch...      1  0.468428
# 4088  xong ning giang toang rồi ninh_giang dính covi...      1  0.051228
# 4090  du_khách trung_quốc đầu_tiên chết vì virus cov...      1  0.708130
#
#            POS       NEU  num_word  num_char  num_hashtag  num_url  \
# 5     0.963102  0.031501        17        80            0        0
# 11    0.946044  0.046785         5        56            0        0
# 12    0.016469  0.018424        83       457            0        0
# 14    0.834880  0.098371       195       897            0        0
# 18    0.063569  0.734244        14        58            0        0
# ...        ...       ...       ...       ...          ...      ...
# 3978  0.007577  0.021508        68       348            0        0
# 4003  0.087048  0.733249        51       266            0        0
# 4066  0.039129  0.492443       236      1227            0        0
# 4088  0.080587  0.868185        12        73            0        0
# 4090  0.042828  0.249042        92       483            0        0
#
#      num_like_post num_comment_post num_share_post  hour  weekday  day  month  \
# 5          unknown          unknown        unknown     5        6    9      8
# 11         unknown          unknown        unknown     2        1   30      6
# 12         unknown          unknown        unknown    13        2   20      5
# 14         unknown          unknown        unknown     8        0   24      2
# 18         unknown          unknown        unknown     0        3   16      4
# ...            ...              ...            ...   ...      ...  ...    ...
# 3978       unknown          unknown        unknown     3        3    6      2
# 4003       unknown          unknown        unknown     8        0    9      3
# 4066       unknown          unknown        unknown     1        6   18      8
# 4088       unknown          unknown        unknown    15        6   26      7
# 4090       unknown          unknown        unknown     3        0   27      1
#
#       year
# 5     2020
# 11    2020
# 12    2020
# 14    2020
# 18    2020
# ...    ...
# 3978  2020
# 4003  2020
# 4066  2019
# 4088  2020
# 4090  2020
#
# [117 rows x 17 columns]

# %%
df[df['num_share_post'] == '1 share']
# Out:
#                                              preprocess  label       NEG  \
# 6     tin chấn_động nhân_loại được cứu 100 người thử...      1  0.003936
# 54    người đàn_ông hồi_giáo tươi_cười khi nhà_thờ đ...      1  0.027069
# 58    ngay cả khí_vị rút xâm_nhập vào miệng bạn nước...      1  0.066796
# 168   bcao cô và các bố_mẹ e vừa dự cuộc họp khẩn củ...      1  0.212937
# 172   tối nay từ 11 40 tối không ai nên đi ra đường ...      1  0.948462
# 175   bài_thuốc mỗi sáng khiến tôi khoẻ_mạnh khuyến_...      1  0.005189
# 889   mọi người cảnh_giác nhé trưa hôm_nay cô_mình m...      1  0.980942
# 1332  thuốc chữa sốt_rét chữa covid ở mỹ trung hay b...      1  0.028625
# 1483  nhóm du_khách hàn_quốc sau khi từ_chối cách_ly...      1  0.984078
# 2178  bcao cô và các bố_mẹ e vừa dự cuộc họp khẩn củ...      1  0.212937
# 2376  ngay cả khí_vị rút xâm_nhập vào miệng bạn nước...      1  0.066796
# 3129  bài_thuốc mỗi sáng khiến tôi khoẻ_mạnh khuyến_...      1  0.005189
# 3681  người đàn_ông hồi_giáo tươi_cười khi nhà_thờ đ...      1  0.027069
# 3746  trung_quốc muốn ý mua lại chính vật_tư y_tế tr...      1  0.152512
#
#            POS       NEU  num_word  num_char  num_hashtag  num_url  \
# 6     0.972723  0.023342        62       328            0        0
# 54    0.181464  0.791467        17       100            0        0
# 58    0.518836  0.414368        37       197            0        0
# 168   0.151256  0.635807       201       974            0        0
# 172   0.028394  0.023144        42       235            0        0
# 175   0.983623  0.011189        81       458            0        0
# 889   0.005269  0.013790        46       212            0        0
# 1332  0.550837  0.420538        38       188            0        0
# 1483  0.003857  0.012064        30       177            0        0
# 2178  0.151256  0.635807       201       974            0        0
# 2376  0.518836  0.414368        37       197            0        0
# 3129  0.983623  0.011189        81       458            0        0
# 3681  0.181464  0.791467        17       100            0        0
# 3746  0.048125  0.799363        16        78            0        0
#
#      num_like_post num_comment_post num_share_post  hour  weekday  day  month  \
# 6               21                5        1 share    15        4   20      3
# 54              82               13        1 share    15        2   15      4
# 58              17                2        1 share    16        5   29      2
# 168             55                4        1 share     8        2   18      3
# 172             70                5        1 share     5        6   29      3
# 175             10                5        1 share    11        2   29      4
# 889             91               33        1 share    14        6   10      3
# 1332            55               24        1 share    19        0   23      3
# 1483            32               22        1 share    15        2   26      2
# 2178            55                4        1 share     8        2   18      3
# 2376            17                2        1 share    16        5   29      2
# 3129            10                5        1 share    11        2   29      4
# 3681            82               13        1 share    15        2   15      4
# 3746            30               18        1 share    21        1    7      4
#
#       year
# 6     2020
# 54    2020
# 58    2020
# 168   2020
# 172   2020
# 175   2020
# 889   2019
# 1332  2020
# 1483  2020
# 2178  2020
# 2376  2020
# 3129  2020
# 3681  2020
# 3746  2020

# %%
df[df['num_comment_post'] == '1 comment']
# Out:
#                                              preprocess  label       NEG  \
# 36    phó chủ_tịch thường_trực ubnd thành_phố hồ_chí...      1  0.985244
# 48    lô thuốc đầu_tiên chữa khỏi bệnh viêm phổi vir...      1  0.006129
# 151   tỷ_phú bill gates là người tung virus covid qu...      1  0.052209
# 725             à nội đã hoãn giải đua f1 do dịch covid      0  0.092729
# 812   phó chủ_tịch thường_trực ubnd thành_phố hồ_chí...      1  0.985244
# 2427  nghi_ngờ virus 2019 covid là vũ_khí_sinh_học b...      1  0.944405
# 3182  lô thuốc đầu_tiên chữa khỏi bệnh viêm phổi vir...      1  0.006129
# 3658  nếu ai định đi du_lịch đặt vé máy_bay thì hay ...      1  0.030938
#
#            POS       NEU  num_word  num_char  num_hashtag  num_url  \
# 36    0.004743  0.010013        60       305            0        0
# 48    0.906991  0.086880        17        88            0        0
# 151   0.056453  0.891337        13        83            0        0
# 725   0.070392  0.836880         9        43            0        0
# 812   0.004743  0.010013        60       305            0        0
# 2427  0.011982  0.043612        55       368            0        0
# 3182  0.906991  0.086880        17        88            0        0
# 3658  0.105952  0.863110        52       250            0        0
#
#      num_like_post num_comment_post num_share_post  hour  weekday  day  month  \
# 36              16        1 comment              0     9        0   30      3
# 48              12        1 comment              0    14        2   18      3
# 151             21        1 comment              0     6        2    5      2
# 725             29        1 comment              0    15        5    7      3
# 812             16        1 comment              0     9        0   30      3
# 2427            20        1 comment              6     6        2    5      2
# 3182            12        1 comment              0    14        2   18      3
# 3658            10        1 comment              0     5        2   29      7
#
#       year
# 36    2020
# 48    2020
# 151   2020
# 725   2020
# 812   2020
# 2427  2020
# 3182  2020
# 3658  2020

# %%
df[df['num_like_post'] == '1 like']
# Out:
# Empty DataFrame
# Columns: [preprocess, label, NEG, POS, NEU, num_word, num_char, num_hashtag, num_url, num_like_post, num_comment_post, num_share_post, hour, weekday, day, month, year]
# Index: []

# %%
df['num_comment_post'] = df['num_comment_post'].replace('1 comment', '1')
df['num_share_post'] = df['num_share_post'].replace('1 share', '1')

# %%
df['num_comment_post'] = df['num_comment_post'].astype(str)
df['num_comment_post'] = df['num_comment_post'].where(~df['num_comment_post'].str.contains(r'[a-zA-Z]'), other=None)

# %%
df['num_like_post'] = df['num_like_post'].astype(str)
df['num_like_post'] = df['num_like_post'].where(~df['num_like_post'].str.contains(r'[a-zA-Z]'), other=None)

# %%
df['num_share_post'] = df['num_share_post'].astype(str)
df['num_share_post'] = df['num_share_post'].where(~df['num_share_post'].str.contains(r'[a-zA-Z]'), other=None)

# %%
df['num_share_post'] = pd.to_numeric(df['num_share_post'], errors='coerce').astype(np.int64)
df['num_like_post'] = pd.to_numeric(df['num_like_post'], errors='coerce').astype(np.int64)
df['num_comment_post'] = pd.to_numeric(df['num_comment_post'], errors='coerce').astype(np.64)

# %%
mean_share = df['num_share_post'].mean()
mean_share = round(mean_share)
print((mean_share))
# Out:
# 475.3860955927995

# %%
mean_comment = df['num_comment_post'].mean()
mean_comment = round(mean_comment)
print((mean_comment))
# Out:
# 123.70842767295598

# %%
mean_like = df['num_like_post'].mean()
mean_like = round(mean_like)
print((mean_like))
# Out:
# 1885.0152101056974

# %%
df['num_share_post'] = df['num_share_post'].fillna(mean_share)
df['num_comment_post'] = df['num_comment_post'].fillna(mean_comment)
df['num_like_post'] = df['num_like_post'].fillna(mean_like)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4106 entries, 0 to 4105
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   preprocess        4106 non-null   object
#  1   label             4106 non-null   int64
#  2   NEG               4106 non-null   float64
#  3   POS               4106 non-null   float64
#  4   NEU               4106 non-null   float64
#  5   num_word          4106 non-null   int64
#  6   num_char          4106 non-null   int64
#  7   num_hashtag       4106 non-null   int64
#  8   num_url           4106 non-null   int64
#  9   num_like_post     4106 non-null   float64
#  10  num_comment_post  4106 non-null   float64
#  11  num_share_post    4106 non-null   float64
#  12  hour              4106 non-null   int64
#  13  weekday           4106 non-null   int64
#  14  day               4106 non-null   int64
#  15  month             4106 non-null   int64
#  16  year              4106 non-null   int64
# dtypes: float64(6), int64(10), object(1)
# memory usage: 545.5+ KB
# None

# %%
df.head()
# Out:
#                                           preprocess  label       NEG  \
# 0  cần các bậc phụ_huynh xã ngũ thái lên_tiếng kh...      1  0.985327
# 1  kêu_gọi ăn_chay cầu_nguyện xin chúa cứu khỏi d...      1  0.659123
# 2  giàn khoan dầu_khí gặp sự_cố chết người giàn k...      1  0.929886
# 3  thuận_lợi có ca dương_tính cv19 rồi đó mọi ngư...      1  0.004563
# 4  sa_pa cho 9 người khách nước_ngoài đi cùng chu...      1  0.038136
#
#         POS       NEU  num_word  num_char  num_hashtag  num_url  \
# 0  0.004864  0.009808        34       182            0        0
# 1  0.213645  0.127232        10        62            0        0
# 2  0.016793  0.053320        41       212            0        0
# 3  0.982044  0.013393        28       151            0        0
# 4  0.090191  0.871673        13        65            0        0
#
#    num_like_post  num_comment_post  num_share_post  hour  weekday  day  month  \
# 0           45.0              15.0             8.0     6        1   17      3
# 1          979.0              39.0           138.0    19        0   10      2
# 2           85.0              13.0            61.0    12        3   16      4
# 3          114.0              12.0             5.0    10        0    3      8
# 4          166.0               4.0            21.0     2        5    7      3
#
#    year
# 0  2020
# 1  2020
# 2  2020
# 3  2020
# 4  2020

# %%
df.to_csv('Data/data_after_preprocessing_text_sa_timestamp_numeric.csv')

# %%
pd.DataFrame(df['label'].value_counts())
# Out:
#    label
# 0   3348
# 1    758
